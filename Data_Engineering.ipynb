# %% [markdown]
# # 1. ***INTRODUCTION***

# %% [markdown]
# * **Data Ingestion** is the process of **extracting** unstructured data from a source, transporting it to a suitable environment, and preparing it for use. This often include **normalizing**, **cleaning** and adding **metadata**
#
# Data Engineers are the architects behind:
# * **building** reliable, efficient and scalable  pipelines.
# * **optimize data storage** to keep cost low and performance high.
# * **ensure data quality and integrity**, addressing duplicates, inconsistencies and missing values.
# * **implement data governance**, for secure, compliance and well-managed data.
# * **adapt data architectures** to meet changing needs of the organization.
#
# Ultimately, data engineers manage the entire **data lifecycle**, from collection to consumption.
#
# ### **Extracting Data**
#
# **Data Streaming vs Batching**
#
# When extracting data, you need to decide **how** to process it:
# * **Batching**: processing data in chunks at scheduled intervals. Suitable for scheduled task and reduce system loads.
# * **Streaming**: processing data continuously as it arrives. ideal for real-time data processing and immediate insights.

# %% [markdown]
# ## 2. ***Working with REST APIs (APIs as a Data Source)***
#
# APIs are a major source of data ingestion. depending on how APIs provide data, they can be used in both **Batch and Streaming** workflows.
#
# 1. **APIs for batch extraction**: Some APIs return large datasets at once. The data is often fetched on a schedule or as part of an ETL process.
#
# **Common batch API examples**
# * **CRM APIs (Salesforce, HubSpot)** - Export customer data daily.
# * **E-Commerce APIs (Shopify, Amazon)** - Downloads product catalogue or sales report periodically.
# * **Public APIs (Weather, Financial Data)** - Receives daily stocks and markets updates.
#
# **How batch API extraction works**:
# 1. Call an API at **scheduled intervals** (eg. every hour or every day)
# 2. Retrieve all available data (eg. last 24 hours of records)
# 3. Store results in a database, data warehouse, or file storage.

# %%
# Get data with request library
import requests

url = 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/events'

response = requests.get(url)
data = response.json()
data
# Out:
# [{'id': '48993156691',
#   'type': 'WatchEvent',
#   'actor': {'id': 129647123,
#    'login': 'Abdullakhan110100100',
#    'display_login': 'Abdullakhan110100100',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Abdullakhan110100100',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/129647123?'},
#   'repo': {'id': 419661684,
#    'name': 'DataTalksClub/data-engineering-zoomcamp',
#    'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2025-04-23T21:19:12Z',
#   'org': {'id': 72699292,
#    'login': 'DataTalksClub',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/DataTalksClub',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}},
#  {'id': '48992523734',
#   'type': 'WatchEvent',
#   'actor': {'id': 204797752,
#    'login': 'rodrigues39',
#    'display_login': 'rodrigues39',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/rodrigues39',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/204797752?'},
#   'repo': {'id': 419661684,
#    'name': 'DataTalksClub/data-engineering-zoomcamp',
#    'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2025-04-23T20:57:36Z',
#   'org': {'id': 72699292,
#    'login': 'DataTalksClub',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/DataTalksClub',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}},
#  {'id': '48990903472',
#   'type': 'WatchEvent',
#   'actor': {'id': 208870789,
#    'login': 'AndresMLopez',
#    'display_login': 'AndresMLopez',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/AndresMLopez',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/208870789?'},
#   'repo': {'id': 419661684,
#    'name': 'DataTalksClub/data-engineering-zoomcamp',
#    'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2025-04-23T20:05:04Z',
#   'org': {'id': 72699292,
#    'login': 'DataTalksClub',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/DataTalksClub',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}},
#  {'id': '48990405965',
#   'type': 'ForkEvent',
#   'actor': {'id': 53873343,
#    'login': 'JaquanAhmed',
#    'display_login': 'JaquanAhmed',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/JaquanAhmed',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/53873343?'},
#   'repo': {'id': 419661684,
#    'name': 'DataTalksClub/data-engineering-zoomcamp',
#    'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'},
#   'payload': {'forkee': {'id': 971617964,
#     'node_id': 'R_kgDOOem2rA',
#     'name': 'data-engineering-zoomcamp',
#     'full_name': 'JaquanAhmed/data-engineering-zoomcamp',
#     'private': False,
#     'owner': {'login': 'JaquanAhmed',
#      'id': 53873343,
#      'node_id': 'MDQ6VXNlcjUzODczMzQz',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/53873343?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/JaquanAhmed',
#      'html_url': 'https://github.com/JaquanAhmed',
#      'followers_url': 'https://api.github.com/users/JaquanAhmed/followers',
#      'following_url': 'https://api.github.com/users/JaquanAhmed/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/JaquanAhmed/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/JaquanAhmed/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/JaquanAhmed/subscriptions',
#      'organizations_url': 'https://api.github.com/users/JaquanAhmed/orgs',
#      'repos_url': 'https://api.github.com/users/JaquanAhmed/repos',
#      'events_url': 'https://api.github.com/users/JaquanAhmed/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/JaquanAhmed/received_events',
#      'type': 'User',
#      'user_view_type': 'public',
#      'site_admin': False},
#     'html_url': 'https://github.com/JaquanAhmed/data-engineering-zoomcamp',
#     'description': 'Data Engineering Zoomcamp is a free nine-week course that covers the fundamentals of data engineering.',
#     'fork': True,
#     'url': 'https://api.github.com/repos/JaquanAhmed/data-engineering-zoomcamp',
#     'forks_url': 'https://api.github.com/repos/JaquanAhmed/data-engineering-zoomcamp/forks',
#     'keys_url': 'https://api.github.com/repos/JaquanAhmed/data-engineering-zoomcamp/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/JaquanAhmed/data-engineering-zoomcamp/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/JaquanAhmed/data-engineering-zoomcamp/teams',
#     'hooks_url': 'https://api.github.com/repos/JaquanAhmed/data-engineering-zoomcamp/hooks',
#     'issue_events_url': 'https://api.github.com/repos/JaquanAhmed/data-engineering-zoomcamp/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/JaquanAhmed/data-engineering-zoomcamp/events',
#     'assignees_url': 'https://api.github.com/repos/JaquanAhmed/data-engineering-zoomcamp/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/JaquanAhmed/data-engineering-zoomcamp/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/JaquanAhmed/data-engineering-zoomcamp/tags',
#     'blobs_url': 'https://api.github.com/repos/JaquanAhmed/data-engineering-zoomcamp/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/JaquanAhmed/data-engineering-zoomcamp/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/JaquanAhmed/data-engineering-zoomcamp/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/JaquanAhmed/data-engineering-zoomcamp/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/JaquanAhmed/data-engineering-zoomcamp/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/JaquanAhmed/data-engineering-zoomcamp/languages',
#     'stargazers_url': 'https://api.github.com/repos/JaquanAhmed/data-engineering-zoomcamp/stargazers',
#     'contributors_url': 'https://api.github.com/repos/JaquanAhmed/data-engineering-zoomcamp/contributors',
#     'subscribers_url': 'https://api.github.com/repos/JaquanAhmed/data-engineering-zoomcamp/subscribers',
#     'subscription_url': 'https://api.github.com/repos/JaquanAhmed/data-engineering-zoomcamp/subscription',
#     'commits_url': 'https://api.github.com/repos/JaquanAhmed/data-engineering-zoomcamp/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/JaquanAhmed/data-engineering-zoomcamp/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/JaquanAhmed/data-engineering-zoomcamp/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/JaquanAhmed/data-engineering-zoomcamp/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/JaquanAhmed/data-engineering-zoomcamp/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/JaquanAhmed/data-engineering-zoomcamp/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/JaquanAhmed/data-engineering-zoomcamp/merges',
#     'archive_url': 'https://api.github.com/repos/JaquanAhmed/data-engineering-zoomcamp/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/JaquanAhmed/data-engineering-zoomcamp/downloads',
#     'issues_url': 'https://api.github.com/repos/JaquanAhmed/data-engineering-zoomcamp/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/JaquanAhmed/data-engineering-zoomcamp/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/JaquanAhmed/data-engineering-zoomcamp/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/JaquanAhmed/data-engineering-zoomcamp/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/JaquanAhmed/data-engineering-zoomcamp/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/JaquanAhmed/data-engineering-zoomcamp/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/JaquanAhmed/data-engineering-zoomcamp/deployments',
#     'created_at': '2025-04-23T19:49:35Z',
#     'updated_at': '2025-04-23T19:49:35Z',
#     'pushed_at': '2025-04-18T15:51:45Z',
#     'git_url': 'git://github.com/JaquanAhmed/data-engineering-zoomcamp.git',
#     'ssh_url': 'git@github.com:JaquanAhmed/data-engineering-zoomcamp.git',
#     'clone_url': 'https://github.com/JaquanAhmed/data-engineering-zoomcamp.git',
#     'svn_url': 'https://github.com/JaquanAhmed/data-engineering-zoomcamp',
#     'homepage': '',
#     'size': 8732,
#     'stargazers_count': 0,
#     'watchers_count': 0,
#     'language': None,
#     'has_issues': False,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': True,
#     'has_pages': False,
#     'has_discussions': False,
#     'forks_count': 0,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 0,
#     'license': None,
#     'allow_forking': True,
#     'is_template': False,
#     'web_commit_signoff_required': False,
#     'topics': [],
#     'visibility': 'public',
#     'forks': 0,
#     'open_issues': 0,
#     'watchers': 0,
#     'default_branch': 'main',
#     'public': True}},
#   'public': True,
#   'created_at': '2025-04-23T19:49:36Z',
#   'org': {'id': 72699292,
#    'login': 'DataTalksClub',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/DataTalksClub',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}},
#  {'id': '48988597460',
#   'type': 'WatchEvent',
#   'actor': {'id': 164634793,
#    'login': 'ZiluJin',
#    'display_login': 'ZiluJin',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ZiluJin',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/164634793?'},
#   'repo': {'id': 419661684,
#    'name': 'DataTalksClub/data-engineering-zoomcamp',
#    'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2025-04-23T18:54:06Z',
#   'org': {'id': 72699292,
#    'login': 'DataTalksClub',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/DataTalksClub',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}},
#  {'id': '48988251879',
#   'type': 'WatchEvent',
#   'actor': {'id': 104189396,
#    'login': 'swagatskalita092',
#    'display_login': 'swagatskalita092',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/swagatskalita092',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/104189396?'},
#   'repo': {'id': 419661684,
#    'name': 'DataTalksClub/data-engineering-zoomcamp',
#    'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2025-04-23T18:44:05Z',
#   'org': {'id': 72699292,
#    'login': 'DataTalksClub',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/DataTalksClub',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}},
#  {'id': '48985137146',
#   'type': 'WatchEvent',
#   'actor': {'id': 208849487,
#    'login': 'trupt017',
#    'display_login': 'trupt017',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/trupt017',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/208849487?'},
#   'repo': {'id': 419661684,
#    'name': 'DataTalksClub/data-engineering-zoomcamp',
#    'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2025-04-23T17:15:03Z',
#   'org': {'id': 72699292,
#    'login': 'DataTalksClub',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/DataTalksClub',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}},
#  {'id': '48983207930',
#   'type': 'ForkEvent',
#   'actor': {'id': 90868038,
#    'login': 'giuseppecardinale7',
#    'display_login': 'giuseppecardinale7',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/giuseppecardinale7',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/90868038?'},
#   'repo': {'id': 419661684,
#    'name': 'DataTalksClub/data-engineering-zoomcamp',
#    'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'},
#   'payload': {'forkee': {'id': 971511237,
#     'node_id': 'R_kgDOOegVxQ',
#     'name': 'data-engineering-zoomcamp',
#     'full_name': 'giuseppecardinale7/data-engineering-zoomcamp',
#     'private': False,
#     'owner': {'login': 'giuseppecardinale7',
#      'id': 90868038,
#      'node_id': 'MDQ6VXNlcjkwODY4MDM4',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/90868038?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/giuseppecardinale7',
#      'html_url': 'https://github.com/giuseppecardinale7',
#      'followers_url': 'https://api.github.com/users/giuseppecardinale7/followers',
#      'following_url': 'https://api.github.com/users/giuseppecardinale7/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/giuseppecardinale7/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/giuseppecardinale7/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/giuseppecardinale7/subscriptions',
#      'organizations_url': 'https://api.github.com/users/giuseppecardinale7/orgs',
#      'repos_url': 'https://api.github.com/users/giuseppecardinale7/repos',
#      'events_url': 'https://api.github.com/users/giuseppecardinale7/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/giuseppecardinale7/received_events',
#      'type': 'User',
#      'user_view_type': 'public',
#      'site_admin': False},
#     'html_url': 'https://github.com/giuseppecardinale7/data-engineering-zoomcamp',
#     'description': 'Data Engineering Zoomcamp is a free nine-week course that covers the fundamentals of data engineering.',
#     'fork': True,
#     'url': 'https://api.github.com/repos/giuseppecardinale7/data-engineering-zoomcamp',
#     'forks_url': 'https://api.github.com/repos/giuseppecardinale7/data-engineering-zoomcamp/forks',
#     'keys_url': 'https://api.github.com/repos/giuseppecardinale7/data-engineering-zoomcamp/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/giuseppecardinale7/data-engineering-zoomcamp/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/giuseppecardinale7/data-engineering-zoomcamp/teams',
#     'hooks_url': 'https://api.github.com/repos/giuseppecardinale7/data-engineering-zoomcamp/hooks',
#     'issue_events_url': 'https://api.github.com/repos/giuseppecardinale7/data-engineering-zoomcamp/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/giuseppecardinale7/data-engineering-zoomcamp/events',
#     'assignees_url': 'https://api.github.com/repos/giuseppecardinale7/data-engineering-zoomcamp/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/giuseppecardinale7/data-engineering-zoomcamp/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/giuseppecardinale7/data-engineering-zoomcamp/tags',
#     'blobs_url': 'https://api.github.com/repos/giuseppecardinale7/data-engineering-zoomcamp/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/giuseppecardinale7/data-engineering-zoomcamp/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/giuseppecardinale7/data-engineering-zoomcamp/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/giuseppecardinale7/data-engineering-zoomcamp/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/giuseppecardinale7/data-engineering-zoomcamp/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/giuseppecardinale7/data-engineering-zoomcamp/languages',
#     'stargazers_url': 'https://api.github.com/repos/giuseppecardinale7/data-engineering-zoomcamp/stargazers',
#     'contributors_url': 'https://api.github.com/repos/giuseppecardinale7/data-engineering-zoomcamp/contributors',
#     'subscribers_url': 'https://api.github.com/repos/giuseppecardinale7/data-engineering-zoomcamp/subscribers',
#     'subscription_url': 'https://api.github.com/repos/giuseppecardinale7/data-engineering-zoomcamp/subscription',
#     'commits_url': 'https://api.github.com/repos/giuseppecardinale7/data-engineering-zoomcamp/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/giuseppecardinale7/data-engineering-zoomcamp/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/giuseppecardinale7/data-engineering-zoomcamp/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/giuseppecardinale7/data-engineering-zoomcamp/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/giuseppecardinale7/data-engineering-zoomcamp/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/giuseppecardinale7/data-engineering-zoomcamp/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/giuseppecardinale7/data-engineering-zoomcamp/merges',
#     'archive_url': 'https://api.github.com/repos/giuseppecardinale7/data-engineering-zoomcamp/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/giuseppecardinale7/data-engineering-zoomcamp/downloads',
#     'issues_url': 'https://api.github.com/repos/giuseppecardinale7/data-engineering-zoomcamp/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/giuseppecardinale7/data-engineering-zoomcamp/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/giuseppecardinale7/data-engineering-zoomcamp/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/giuseppecardinale7/data-engineering-zoomcamp/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/giuseppecardinale7/data-engineering-zoomcamp/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/giuseppecardinale7/data-engineering-zoomcamp/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/giuseppecardinale7/data-engineering-zoomcamp/deployments',
#     'created_at': '2025-04-23T16:22:45Z',
#     'updated_at': '2025-04-23T16:22:45Z',
#     'pushed_at': '2025-04-18T15:51:45Z',
#     'git_url': 'git://github.com/giuseppecardinale7/data-engineering-zoomcamp.git',
#     'ssh_url': 'git@github.com:giuseppecardinale7/data-engineering-zoomcamp.git',
#     'clone_url': 'https://github.com/giuseppecardinale7/data-engineering-zoomcamp.git',
#     'svn_url': 'https://github.com/giuseppecardinale7/data-engineering-zoomcamp',
#     'homepage': '',
#     'size': 8732,
#     'stargazers_count': 0,
#     'watchers_count': 0,
#     'language': None,
#     'has_issues': False,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': True,
#     'has_pages': False,
#     'has_discussions': False,
#     'forks_count': 0,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 0,
#     'license': None,
#     'allow_forking': True,
#     'is_template': False,
#     'web_commit_signoff_required': False,
#     'topics': [],
#     'visibility': 'public',
#     'forks': 0,
#     'open_issues': 0,
#     'watchers': 0,
#     'default_branch': 'main',
#     'public': True}},
#   'public': True,
#   'created_at': '2025-04-23T16:22:46Z',
#   'org': {'id': 72699292,
#    'login': 'DataTalksClub',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/DataTalksClub',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}},
#  {'id': '48978421112',
#   'type': 'WatchEvent',
#   'actor': {'id': 64391407,
#    'login': 'limits-to-arbitrage',
#    'display_login': 'limits-to-arbitrage',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/limits-to-arbitrage',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/64391407?'},
#   'repo': {'id': 419661684,
#    'name': 'DataTalksClub/data-engineering-zoomcamp',
#    'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2025-04-23T14:33:07Z',
#   'org': {'id': 72699292,
#    'login': 'DataTalksClub',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/DataTalksClub',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}},
#  {'id': '48977194704',
#   'type': 'WatchEvent',
#   'actor': {'id': 67238735,
#    'login': 'Estella777',
#    'display_login': 'Estella777',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Estella777',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/67238735?'},
#   'repo': {'id': 419661684,
#    'name': 'DataTalksClub/data-engineering-zoomcamp',
#    'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2025-04-23T14:08:12Z',
#   'org': {'id': 72699292,
#    'login': 'DataTalksClub',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/DataTalksClub',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}},
#  {'id': '48976073285',
#   'type': 'ForkEvent',
#   'actor': {'id': 25983291,
#    'login': 'bark-biiga',
#    'display_login': 'bark-biiga',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/bark-biiga',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/25983291?'},
#   'repo': {'id': 419661684,
#    'name': 'DataTalksClub/data-engineering-zoomcamp',
#    'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'},
#   'payload': {'forkee': {'id': 971417156,
#     'node_id': 'R_kgDOOeamRA',
#     'name': 'data-engineering-zoomcamp',
#     'full_name': 'bark-biiga/data-engineering-zoomcamp',
#     'private': False,
#     'owner': {'login': 'bark-biiga',
#      'id': 25983291,
#      'node_id': 'MDQ6VXNlcjI1OTgzMjkx',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/25983291?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/bark-biiga',
#      'html_url': 'https://github.com/bark-biiga',
#      'followers_url': 'https://api.github.com/users/bark-biiga/followers',
#      'following_url': 'https://api.github.com/users/bark-biiga/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/bark-biiga/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/bark-biiga/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/bark-biiga/subscriptions',
#      'organizations_url': 'https://api.github.com/users/bark-biiga/orgs',
#      'repos_url': 'https://api.github.com/users/bark-biiga/repos',
#      'events_url': 'https://api.github.com/users/bark-biiga/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/bark-biiga/received_events',
#      'type': 'User',
#      'user_view_type': 'public',
#      'site_admin': False},
#     'html_url': 'https://github.com/bark-biiga/data-engineering-zoomcamp',
#     'description': 'Data Engineering Zoomcamp is a free nine-week course that covers the fundamentals of data engineering.',
#     'fork': True,
#     'url': 'https://api.github.com/repos/bark-biiga/data-engineering-zoomcamp',
#     'forks_url': 'https://api.github.com/repos/bark-biiga/data-engineering-zoomcamp/forks',
#     'keys_url': 'https://api.github.com/repos/bark-biiga/data-engineering-zoomcamp/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/bark-biiga/data-engineering-zoomcamp/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/bark-biiga/data-engineering-zoomcamp/teams',
#     'hooks_url': 'https://api.github.com/repos/bark-biiga/data-engineering-zoomcamp/hooks',
#     'issue_events_url': 'https://api.github.com/repos/bark-biiga/data-engineering-zoomcamp/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/bark-biiga/data-engineering-zoomcamp/events',
#     'assignees_url': 'https://api.github.com/repos/bark-biiga/data-engineering-zoomcamp/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/bark-biiga/data-engineering-zoomcamp/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/bark-biiga/data-engineering-zoomcamp/tags',
#     'blobs_url': 'https://api.github.com/repos/bark-biiga/data-engineering-zoomcamp/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/bark-biiga/data-engineering-zoomcamp/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/bark-biiga/data-engineering-zoomcamp/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/bark-biiga/data-engineering-zoomcamp/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/bark-biiga/data-engineering-zoomcamp/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/bark-biiga/data-engineering-zoomcamp/languages',
#     'stargazers_url': 'https://api.github.com/repos/bark-biiga/data-engineering-zoomcamp/stargazers',
#     'contributors_url': 'https://api.github.com/repos/bark-biiga/data-engineering-zoomcamp/contributors',
#     'subscribers_url': 'https://api.github.com/repos/bark-biiga/data-engineering-zoomcamp/subscribers',
#     'subscription_url': 'https://api.github.com/repos/bark-biiga/data-engineering-zoomcamp/subscription',
#     'commits_url': 'https://api.github.com/repos/bark-biiga/data-engineering-zoomcamp/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/bark-biiga/data-engineering-zoomcamp/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/bark-biiga/data-engineering-zoomcamp/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/bark-biiga/data-engineering-zoomcamp/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/bark-biiga/data-engineering-zoomcamp/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/bark-biiga/data-engineering-zoomcamp/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/bark-biiga/data-engineering-zoomcamp/merges',
#     'archive_url': 'https://api.github.com/repos/bark-biiga/data-engineering-zoomcamp/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/bark-biiga/data-engineering-zoomcamp/downloads',
#     'issues_url': 'https://api.github.com/repos/bark-biiga/data-engineering-zoomcamp/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/bark-biiga/data-engineering-zoomcamp/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/bark-biiga/data-engineering-zoomcamp/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/bark-biiga/data-engineering-zoomcamp/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/bark-biiga/data-engineering-zoomcamp/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/bark-biiga/data-engineering-zoomcamp/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/bark-biiga/data-engineering-zoomcamp/deployments',
#     'created_at': '2025-04-23T13:44:45Z',
#     'updated_at': '2025-04-23T13:44:45Z',
#     'pushed_at': '2025-04-18T15:51:45Z',
#     'git_url': 'git://github.com/bark-biiga/data-engineering-zoomcamp.git',
#     'ssh_url': 'git@github.com:bark-biiga/data-engineering-zoomcamp.git',
#     'clone_url': 'https://github.com/bark-biiga/data-engineering-zoomcamp.git',
#     'svn_url': 'https://github.com/bark-biiga/data-engineering-zoomcamp',
#     'homepage': '',
#     'size': 8732,
#     'stargazers_count': 0,
#     'watchers_count': 0,
#     'language': None,
#     'has_issues': False,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': True,
#     'has_pages': False,
#     'has_discussions': False,
#     'forks_count': 0,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 0,
#     'license': None,
#     'allow_forking': True,
#     'is_template': False,
#     'web_commit_signoff_required': False,
#     'topics': [],
#     'visibility': 'public',
#     'forks': 0,
#     'open_issues': 0,
#     'watchers': 0,
#     'default_branch': 'main',
#     'public': True}},
#   'public': True,
#   'created_at': '2025-04-23T13:44:46Z',
#   'org': {'id': 72699292,
#    'login': 'DataTalksClub',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/DataTalksClub',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}},
#  {'id': '48972839337',
#   'type': 'WatchEvent',
#   'actor': {'id': 25754442,
#    'login': 'yasmeenel3sh',
#    'display_login': 'yasmeenel3sh',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/yasmeenel3sh',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/25754442?'},
#   'repo': {'id': 419661684,
#    'name': 'DataTalksClub/data-engineering-zoomcamp',
#    'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2025-04-23T12:35:17Z',
#   'org': {'id': 72699292,
#    'login': 'DataTalksClub',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/DataTalksClub',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}},
#  {'id': '48969167980',
#   'type': 'ForkEvent',
#   'actor': {'id': 89593731,
#    'login': 'jaromantuka',
#    'display_login': 'jaromantuka',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jaromantuka',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/89593731?'},
#   'repo': {'id': 419661684,
#    'name': 'DataTalksClub/data-engineering-zoomcamp',
#    'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'},
#   'payload': {'forkee': {'id': 971327773,
#     'node_id': 'R_kgDOOeVJHQ',
#     'name': 'data-engineering-zoomcamp',
#     'full_name': 'jaromantuka/data-engineering-zoomcamp',
#     'private': False,
#     'owner': {'login': 'jaromantuka',
#      'id': 89593731,
#      'node_id': 'MDQ6VXNlcjg5NTkzNzMx',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/89593731?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/jaromantuka',
#      'html_url': 'https://github.com/jaromantuka',
#      'followers_url': 'https://api.github.com/users/jaromantuka/followers',
#      'following_url': 'https://api.github.com/users/jaromantuka/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/jaromantuka/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/jaromantuka/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/jaromantuka/subscriptions',
#      'organizations_url': 'https://api.github.com/users/jaromantuka/orgs',
#      'repos_url': 'https://api.github.com/users/jaromantuka/repos',
#      'events_url': 'https://api.github.com/users/jaromantuka/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/jaromantuka/received_events',
#      'type': 'User',
#      'user_view_type': 'public',
#      'site_admin': False},
#     'html_url': 'https://github.com/jaromantuka/data-engineering-zoomcamp',
#     'description': 'Data Engineering Zoomcamp is a free nine-week course that covers the fundamentals of data engineering.',
#     'fork': True,
#     'url': 'https://api.github.com/repos/jaromantuka/data-engineering-zoomcamp',
#     'forks_url': 'https://api.github.com/repos/jaromantuka/data-engineering-zoomcamp/forks',
#     'keys_url': 'https://api.github.com/repos/jaromantuka/data-engineering-zoomcamp/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/jaromantuka/data-engineering-zoomcamp/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/jaromantuka/data-engineering-zoomcamp/teams',
#     'hooks_url': 'https://api.github.com/repos/jaromantuka/data-engineering-zoomcamp/hooks',
#     'issue_events_url': 'https://api.github.com/repos/jaromantuka/data-engineering-zoomcamp/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/jaromantuka/data-engineering-zoomcamp/events',
#     'assignees_url': 'https://api.github.com/repos/jaromantuka/data-engineering-zoomcamp/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/jaromantuka/data-engineering-zoomcamp/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/jaromantuka/data-engineering-zoomcamp/tags',
#     'blobs_url': 'https://api.github.com/repos/jaromantuka/data-engineering-zoomcamp/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/jaromantuka/data-engineering-zoomcamp/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/jaromantuka/data-engineering-zoomcamp/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/jaromantuka/data-engineering-zoomcamp/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/jaromantuka/data-engineering-zoomcamp/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/jaromantuka/data-engineering-zoomcamp/languages',
#     'stargazers_url': 'https://api.github.com/repos/jaromantuka/data-engineering-zoomcamp/stargazers',
#     'contributors_url': 'https://api.github.com/repos/jaromantuka/data-engineering-zoomcamp/contributors',
#     'subscribers_url': 'https://api.github.com/repos/jaromantuka/data-engineering-zoomcamp/subscribers',
#     'subscription_url': 'https://api.github.com/repos/jaromantuka/data-engineering-zoomcamp/subscription',
#     'commits_url': 'https://api.github.com/repos/jaromantuka/data-engineering-zoomcamp/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/jaromantuka/data-engineering-zoomcamp/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/jaromantuka/data-engineering-zoomcamp/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/jaromantuka/data-engineering-zoomcamp/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/jaromantuka/data-engineering-zoomcamp/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/jaromantuka/data-engineering-zoomcamp/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/jaromantuka/data-engineering-zoomcamp/merges',
#     'archive_url': 'https://api.github.com/repos/jaromantuka/data-engineering-zoomcamp/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/jaromantuka/data-engineering-zoomcamp/downloads',
#     'issues_url': 'https://api.github.com/repos/jaromantuka/data-engineering-zoomcamp/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/jaromantuka/data-engineering-zoomcamp/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/jaromantuka/data-engineering-zoomcamp/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/jaromantuka/data-engineering-zoomcamp/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/jaromantuka/data-engineering-zoomcamp/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/jaromantuka/data-engineering-zoomcamp/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/jaromantuka/data-engineering-zoomcamp/deployments',
#     'created_at': '2025-04-23T11:02:21Z',
#     'updated_at': '2025-04-23T11:02:21Z',
#     'pushed_at': '2025-04-18T15:51:45Z',
#     'git_url': 'git://github.com/jaromantuka/data-engineering-zoomcamp.git',
#     'ssh_url': 'git@github.com:jaromantuka/data-engineering-zoomcamp.git',
#     'clone_url': 'https://github.com/jaromantuka/data-engineering-zoomcamp.git',
#     'svn_url': 'https://github.com/jaromantuka/data-engineering-zoomcamp',
#     'homepage': '',
#     'size': 8732,
#     'stargazers_count': 0,
#     'watchers_count': 0,
#     'language': None,
#     'has_issues': False,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': True,
#     'has_pages': False,
#     'has_discussions': False,
#     'forks_count': 0,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 0,
#     'license': None,
#     'allow_forking': True,
#     'is_template': False,
#     'web_commit_signoff_required': False,
#     'topics': [],
#     'visibility': 'public',
#     'forks': 0,
#     'open_issues': 0,
#     'watchers': 0,
#     'default_branch': 'main',
#     'public': True}},
#   'public': True,
#   'created_at': '2025-04-23T11:02:21Z',
#   'org': {'id': 72699292,
#    'login': 'DataTalksClub',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/DataTalksClub',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}},
#  {'id': '48966350677',
#   'type': 'ForkEvent',
#   'actor': {'id': 79210846,
#    'login': 'Kaung-Si-Thu',
#    'display_login': 'Kaung-Si-Thu',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Kaung-Si-Thu',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/79210846?'},
#   'repo': {'id': 419661684,
#    'name': 'DataTalksClub/data-engineering-zoomcamp',
#    'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'},
#   'payload': {'forkee': {'id': 971292775,
#     'node_id': 'R_kgDOOeTAZw',
#     'name': 'data-engineering-zoomcamp',
#     'full_name': 'Kaung-Si-Thu/data-engineering-zoomcamp',
#     'private': False,
#     'owner': {'login': 'Kaung-Si-Thu',
#      'id': 79210846,
#      'node_id': 'MDQ6VXNlcjc5MjEwODQ2',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/79210846?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/Kaung-Si-Thu',
#      'html_url': 'https://github.com/Kaung-Si-Thu',
#      'followers_url': 'https://api.github.com/users/Kaung-Si-Thu/followers',
#      'following_url': 'https://api.github.com/users/Kaung-Si-Thu/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/Kaung-Si-Thu/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/Kaung-Si-Thu/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/Kaung-Si-Thu/subscriptions',
#      'organizations_url': 'https://api.github.com/users/Kaung-Si-Thu/orgs',
#      'repos_url': 'https://api.github.com/users/Kaung-Si-Thu/repos',
#      'events_url': 'https://api.github.com/users/Kaung-Si-Thu/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/Kaung-Si-Thu/received_events',
#      'type': 'User',
#      'user_view_type': 'public',
#      'site_admin': False},
#     'html_url': 'https://github.com/Kaung-Si-Thu/data-engineering-zoomcamp',
#     'description': 'Data Engineering Zoomcamp is a free nine-week course that covers the fundamentals of data engineering.',
#     'fork': True,
#     'url': 'https://api.github.com/repos/Kaung-Si-Thu/data-engineering-zoomcamp',
#     'forks_url': 'https://api.github.com/repos/Kaung-Si-Thu/data-engineering-zoomcamp/forks',
#     'keys_url': 'https://api.github.com/repos/Kaung-Si-Thu/data-engineering-zoomcamp/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/Kaung-Si-Thu/data-engineering-zoomcamp/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/Kaung-Si-Thu/data-engineering-zoomcamp/teams',
#     'hooks_url': 'https://api.github.com/repos/Kaung-Si-Thu/data-engineering-zoomcamp/hooks',
#     'issue_events_url': 'https://api.github.com/repos/Kaung-Si-Thu/data-engineering-zoomcamp/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/Kaung-Si-Thu/data-engineering-zoomcamp/events',
#     'assignees_url': 'https://api.github.com/repos/Kaung-Si-Thu/data-engineering-zoomcamp/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/Kaung-Si-Thu/data-engineering-zoomcamp/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/Kaung-Si-Thu/data-engineering-zoomcamp/tags',
#     'blobs_url': 'https://api.github.com/repos/Kaung-Si-Thu/data-engineering-zoomcamp/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/Kaung-Si-Thu/data-engineering-zoomcamp/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/Kaung-Si-Thu/data-engineering-zoomcamp/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/Kaung-Si-Thu/data-engineering-zoomcamp/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/Kaung-Si-Thu/data-engineering-zoomcamp/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/Kaung-Si-Thu/data-engineering-zoomcamp/languages',
#     'stargazers_url': 'https://api.github.com/repos/Kaung-Si-Thu/data-engineering-zoomcamp/stargazers',
#     'contributors_url': 'https://api.github.com/repos/Kaung-Si-Thu/data-engineering-zoomcamp/contributors',
#     'subscribers_url': 'https://api.github.com/repos/Kaung-Si-Thu/data-engineering-zoomcamp/subscribers',
#     'subscription_url': 'https://api.github.com/repos/Kaung-Si-Thu/data-engineering-zoomcamp/subscription',
#     'commits_url': 'https://api.github.com/repos/Kaung-Si-Thu/data-engineering-zoomcamp/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/Kaung-Si-Thu/data-engineering-zoomcamp/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/Kaung-Si-Thu/data-engineering-zoomcamp/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/Kaung-Si-Thu/data-engineering-zoomcamp/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/Kaung-Si-Thu/data-engineering-zoomcamp/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/Kaung-Si-Thu/data-engineering-zoomcamp/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/Kaung-Si-Thu/data-engineering-zoomcamp/merges',
#     'archive_url': 'https://api.github.com/repos/Kaung-Si-Thu/data-engineering-zoomcamp/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/Kaung-Si-Thu/data-engineering-zoomcamp/downloads',
#     'issues_url': 'https://api.github.com/repos/Kaung-Si-Thu/data-engineering-zoomcamp/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/Kaung-Si-Thu/data-engineering-zoomcamp/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/Kaung-Si-Thu/data-engineering-zoomcamp/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/Kaung-Si-Thu/data-engineering-zoomcamp/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/Kaung-Si-Thu/data-engineering-zoomcamp/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/Kaung-Si-Thu/data-engineering-zoomcamp/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/Kaung-Si-Thu/data-engineering-zoomcamp/deployments',
#     'created_at': '2025-04-23T09:52:08Z',
#     'updated_at': '2025-04-23T09:52:08Z',
#     'pushed_at': '2025-04-18T15:51:45Z',
#     'git_url': 'git://github.com/Kaung-Si-Thu/data-engineering-zoomcamp.git',
#     'ssh_url': 'git@github.com:Kaung-Si-Thu/data-engineering-zoomcamp.git',
#     'clone_url': 'https://github.com/Kaung-Si-Thu/data-engineering-zoomcamp.git',
#     'svn_url': 'https://github.com/Kaung-Si-Thu/data-engineering-zoomcamp',
#     'homepage': '',
#     'size': 8732,
#     'stargazers_count': 0,
#     'watchers_count': 0,
#     'language': None,
#     'has_issues': False,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': True,
#     'has_pages': False,
#     'has_discussions': False,
#     'forks_count': 0,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 0,
#     'license': None,
#     'allow_forking': True,
#     'is_template': False,
#     'web_commit_signoff_required': False,
#     'topics': [],
#     'visibility': 'public',
#     'forks': 0,
#     'open_issues': 0,
#     'watchers': 0,
#     'default_branch': 'main',
#     'public': True}},
#   'public': True,
#   'created_at': '2025-04-23T09:52:09Z',
#   'org': {'id': 72699292,
#    'login': 'DataTalksClub',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/DataTalksClub',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}},
#  {'id': '48962950935',
#   'type': 'WatchEvent',
#   'actor': {'id': 157479907,
#    'login': 'MarllonDKT',
#    'display_login': 'MarllonDKT',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/MarllonDKT',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/157479907?'},
#   'repo': {'id': 419661684,
#    'name': 'DataTalksClub/data-engineering-zoomcamp',
#    'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2025-04-23T08:33:29Z',
#   'org': {'id': 72699292,
#    'login': 'DataTalksClub',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/DataTalksClub',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}},
#  {'id': '48961735506',
#   'type': 'WatchEvent',
#   'actor': {'id': 80463168,
#    'login': 'MyriamBA',
#    'display_login': 'MyriamBA',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/MyriamBA',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/80463168?'},
#   'repo': {'id': 419661684,
#    'name': 'DataTalksClub/data-engineering-zoomcamp',
#    'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2025-04-23T08:03:16Z',
#   'org': {'id': 72699292,
#    'login': 'DataTalksClub',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/DataTalksClub',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}},
#  {'id': '48958812290',
#   'type': 'WatchEvent',
#   'actor': {'id': 107249365,
#    'login': 'Johndata91',
#    'display_login': 'Johndata91',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Johndata91',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/107249365?'},
#   'repo': {'id': 419661684,
#    'name': 'DataTalksClub/data-engineering-zoomcamp',
#    'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2025-04-23T06:41:11Z',
#   'org': {'id': 72699292,
#    'login': 'DataTalksClub',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/DataTalksClub',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}},
#  {'id': '48957782847',
#   'type': 'WatchEvent',
#   'actor': {'id': 5937006,
#    'login': 'liangqigong',
#    'display_login': 'liangqigong',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/liangqigong',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/5937006?'},
#   'repo': {'id': 419661684,
#    'name': 'DataTalksClub/data-engineering-zoomcamp',
#    'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2025-04-23T06:06:41Z',
#   'org': {'id': 72699292,
#    'login': 'DataTalksClub',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/DataTalksClub',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}},
#  {'id': '48956681057',
#   'type': 'IssuesEvent',
#   'actor': {'id': 173138135,
#    'login': 'heatblasterr',
#    'display_login': 'heatblasterr',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/heatblasterr',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/173138135?'},
#   'repo': {'id': 419661684,
#    'name': 'DataTalksClub/data-engineering-zoomcamp',
#    'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'},
#   'payload': {'action': 'opened',
#    'issue': {'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/issues/726',
#     'repository_url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp',
#     'labels_url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/issues/726/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/issues/726/comments',
#     'events_url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/issues/726/events',
#     'html_url': 'https://github.com/DataTalksClub/data-engineering-zoomcamp/issues/726',
#     'id': 3012725597,
#     'node_id': 'I_kwDOGQOHdM6zkotd',
#     'number': 726,
#     'title': 'there is a mismatch in schema values in Bigquery and stg_green_tripdata',
#     'user': {'login': 'heatblasterr',
#      'id': 173138135,
#      'node_id': 'U_kgDOClHg1w',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/173138135?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/heatblasterr',
#      'html_url': 'https://github.com/heatblasterr',
#      'followers_url': 'https://api.github.com/users/heatblasterr/followers',
#      'following_url': 'https://api.github.com/users/heatblasterr/following{/other_user}',
# ...
#     'reactions': {'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/issues/726/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'timeline_url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/issues/726/timeline',
#     'performed_via_github_app': None,
#     'state_reason': None}},
#   'public': True,
#   'created_at': '2025-04-23T05:22:01Z',
#   'org': {'id': 72699292,
#    'login': 'DataTalksClub',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/DataTalksClub',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}},
#  {'id': '48954667166',
#   'type': 'WatchEvent',
#   'actor': {'id': 51444652,
#    'login': 'ChiungYunChang',
#    'display_login': 'ChiungYunChang',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ChiungYunChang',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/51444652?'},
#   'repo': {'id': 419661684,
#    'name': 'DataTalksClub/data-engineering-zoomcamp',
#    'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2025-04-23T03:41:39Z',
#   'org': {'id': 72699292,
#    'login': 'DataTalksClub',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/DataTalksClub',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}},
#  {'id': '48954246939',
#   'type': 'WatchEvent',
#   'actor': {'id': 142460081,
#    'login': 'danlity0244',
#    'display_login': 'danlity0244',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/danlity0244',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/142460081?'},
#   'repo': {'id': 419661684,
#    'name': 'DataTalksClub/data-engineering-zoomcamp',
#    'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2025-04-23T03:19:12Z',
#   'org': {'id': 72699292,
#    'login': 'DataTalksClub',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/DataTalksClub',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}},
#  {'id': '48952188864',
#   'type': 'WatchEvent',
#   'actor': {'id': 17715612,
#    'login': 'estellezeus',
#    'display_login': 'estellezeus',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/estellezeus',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/17715612?'},
#   'repo': {'id': 419661684,
#    'name': 'DataTalksClub/data-engineering-zoomcamp',
#    'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2025-04-23T01:30:16Z',
#   'org': {'id': 72699292,
#    'login': 'DataTalksClub',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/DataTalksClub',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}},
#  {'id': '48952124339',
#   'type': 'WatchEvent',
#   'actor': {'id': 208734907,
#    'login': 'alyprovy',
#    'display_login': 'alyprovy',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/alyprovy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/208734907?'},
#   'repo': {'id': 419661684,
#    'name': 'DataTalksClub/data-engineering-zoomcamp',
#    'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2025-04-23T01:26:41Z',
#   'org': {'id': 72699292,
#    'login': 'DataTalksClub',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/DataTalksClub',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}},
#  {'id': '48950216740',
#   'type': 'WatchEvent',
#   'actor': {'id': 196280502,
#    'login': 'RayleighFading',
#    'display_login': 'RayleighFading',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/RayleighFading',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/196280502?'},
#   'repo': {'id': 419661684,
#    'name': 'DataTalksClub/data-engineering-zoomcamp',
#    'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2025-04-22T23:39:06Z',
#   'org': {'id': 72699292,
#    'login': 'DataTalksClub',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/DataTalksClub',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}},
#  {'id': '48949776868',
#   'type': 'WatchEvent',
#   'actor': {'id': 164670722,
#    'login': 'Start-Learn-build',
#    'display_login': 'Start-Learn-build',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Start-Learn-build',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/164670722?'},
#   'repo': {'id': 419661684,
#    'name': 'DataTalksClub/data-engineering-zoomcamp',
#    'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2025-04-22T23:14:00Z',
#   'org': {'id': 72699292,
#    'login': 'DataTalksClub',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/DataTalksClub',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}},
#  {'id': '48949510377',
#   'type': 'WatchEvent',
#   'actor': {'id': 151232563,
#    'login': 'Teja8632',
#    'display_login': 'Teja8632',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Teja8632',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/151232563?'},
#   'repo': {'id': 419661684,
#    'name': 'DataTalksClub/data-engineering-zoomcamp',
#    'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2025-04-22T23:00:16Z',
#   'org': {'id': 72699292,
#    'login': 'DataTalksClub',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/DataTalksClub',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}},
#  {'id': '48949405553',
#   'type': 'ForkEvent',
#   'actor': {'id': 2171047,
#    'login': 'biblianthrope',
#    'display_login': 'biblianthrope',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/biblianthrope',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/2171047?'},
#   'repo': {'id': 419661684,
#    'name': 'DataTalksClub/data-engineering-zoomcamp',
#    'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'},
#   'payload': {'forkee': {'id': 971029568,
#     'node_id': 'R_kgDOOeC8QA',
#     'name': 'data-engineering-zoomcamp',
#     'full_name': 'biblianthrope/data-engineering-zoomcamp',
#     'private': False,
#     'owner': {'login': 'biblianthrope',
#      'id': 2171047,
#      'node_id': 'MDQ6VXNlcjIxNzEwNDc=',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/2171047?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/biblianthrope',
#      'html_url': 'https://github.com/biblianthrope',
#      'followers_url': 'https://api.github.com/users/biblianthrope/followers',
#      'following_url': 'https://api.github.com/users/biblianthrope/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/biblianthrope/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/biblianthrope/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/biblianthrope/subscriptions',
#      'organizations_url': 'https://api.github.com/users/biblianthrope/orgs',
#      'repos_url': 'https://api.github.com/users/biblianthrope/repos',
#      'events_url': 'https://api.github.com/users/biblianthrope/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/biblianthrope/received_events',
#      'type': 'User',
#      'user_view_type': 'public',
#      'site_admin': False},
#     'html_url': 'https://github.com/biblianthrope/data-engineering-zoomcamp',
#     'description': 'Data Engineering Zoomcamp is a free nine-week course that covers the fundamentals of data engineering.',
#     'fork': True,
#     'url': 'https://api.github.com/repos/biblianthrope/data-engineering-zoomcamp',
#     'forks_url': 'https://api.github.com/repos/biblianthrope/data-engineering-zoomcamp/forks',
#     'keys_url': 'https://api.github.com/repos/biblianthrope/data-engineering-zoomcamp/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/biblianthrope/data-engineering-zoomcamp/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/biblianthrope/data-engineering-zoomcamp/teams',
#     'hooks_url': 'https://api.github.com/repos/biblianthrope/data-engineering-zoomcamp/hooks',
#     'issue_events_url': 'https://api.github.com/repos/biblianthrope/data-engineering-zoomcamp/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/biblianthrope/data-engineering-zoomcamp/events',
#     'assignees_url': 'https://api.github.com/repos/biblianthrope/data-engineering-zoomcamp/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/biblianthrope/data-engineering-zoomcamp/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/biblianthrope/data-engineering-zoomcamp/tags',
#     'blobs_url': 'https://api.github.com/repos/biblianthrope/data-engineering-zoomcamp/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/biblianthrope/data-engineering-zoomcamp/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/biblianthrope/data-engineering-zoomcamp/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/biblianthrope/data-engineering-zoomcamp/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/biblianthrope/data-engineering-zoomcamp/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/biblianthrope/data-engineering-zoomcamp/languages',
#     'stargazers_url': 'https://api.github.com/repos/biblianthrope/data-engineering-zoomcamp/stargazers',
#     'contributors_url': 'https://api.github.com/repos/biblianthrope/data-engineering-zoomcamp/contributors',
#     'subscribers_url': 'https://api.github.com/repos/biblianthrope/data-engineering-zoomcamp/subscribers',
#     'subscription_url': 'https://api.github.com/repos/biblianthrope/data-engineering-zoomcamp/subscription',
#     'commits_url': 'https://api.github.com/repos/biblianthrope/data-engineering-zoomcamp/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/biblianthrope/data-engineering-zoomcamp/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/biblianthrope/data-engineering-zoomcamp/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/biblianthrope/data-engineering-zoomcamp/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/biblianthrope/data-engineering-zoomcamp/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/biblianthrope/data-engineering-zoomcamp/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/biblianthrope/data-engineering-zoomcamp/merges',
#     'archive_url': 'https://api.github.com/repos/biblianthrope/data-engineering-zoomcamp/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/biblianthrope/data-engineering-zoomcamp/downloads',
#     'issues_url': 'https://api.github.com/repos/biblianthrope/data-engineering-zoomcamp/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/biblianthrope/data-engineering-zoomcamp/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/biblianthrope/data-engineering-zoomcamp/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/biblianthrope/data-engineering-zoomcamp/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/biblianthrope/data-engineering-zoomcamp/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/biblianthrope/data-engineering-zoomcamp/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/biblianthrope/data-engineering-zoomcamp/deployments',
#     'created_at': '2025-04-22T22:54:49Z',
#     'updated_at': '2025-04-22T22:54:49Z',
#     'pushed_at': '2025-04-18T15:51:45Z',
#     'git_url': 'git://github.com/biblianthrope/data-engineering-zoomcamp.git',
#     'ssh_url': 'git@github.com:biblianthrope/data-engineering-zoomcamp.git',
#     'clone_url': 'https://github.com/biblianthrope/data-engineering-zoomcamp.git',
#     'svn_url': 'https://github.com/biblianthrope/data-engineering-zoomcamp',
#     'homepage': '',
#     'size': 8732,
#     'stargazers_count': 0,
#     'watchers_count': 0,
#     'language': None,
#     'has_issues': False,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': True,
#     'has_pages': False,
#     'has_discussions': False,
#     'forks_count': 0,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 0,
#     'license': None,
#     'allow_forking': True,
#     'is_template': False,
#     'web_commit_signoff_required': False,
#     'topics': [],
#     'visibility': 'public',
#     'forks': 0,
#     'open_issues': 0,
#     'watchers': 0,
#     'default_branch': 'main',
#     'public': True}},
#   'public': True,
#   'created_at': '2025-04-22T22:54:49Z',
#   'org': {'id': 72699292,
#    'login': 'DataTalksClub',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/DataTalksClub',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}},
#  {'id': '48949373345',
#   'type': 'WatchEvent',
#   'actor': {'id': 164670722,
#    'login': 'Start-Learn-build',
#    'display_login': 'Start-Learn-build',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Start-Learn-build',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/164670722?'},
#   'repo': {'id': 419661684,
#    'name': 'DataTalksClub/data-engineering-zoomcamp',
#    'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2025-04-22T22:53:02Z',
#   'org': {'id': 72699292,
#    'login': 'DataTalksClub',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/DataTalksClub',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}},
#  {'id': '48947317252',
#   'type': 'WatchEvent',
#   'actor': {'id': 6144022,
#    'login': 'mremane',
#    'display_login': 'mremane',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mremane',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6144022?'},
#   'repo': {'id': 419661684,
#    'name': 'DataTalksClub/data-engineering-zoomcamp',
#    'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2025-04-22T21:22:41Z',
#   'org': {'id': 72699292,
#    'login': 'DataTalksClub',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/DataTalksClub',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}},
#  {'id': '48945891883',
#   'type': 'WatchEvent',
#   'actor': {'id': 18626133,
#    'login': 'lakhanqurban',
#    'display_login': 'lakhanqurban',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/lakhanqurban',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/18626133?'},
#   'repo': {'id': 419661684,
#    'name': 'DataTalksClub/data-engineering-zoomcamp',
#    'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2025-04-22T20:33:54Z',
#   'org': {'id': 72699292,
#    'login': 'DataTalksClub',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/DataTalksClub',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}]

# %% [markdown]
# ## ***3. Common Challenges of API Extraction***
#
# * **Authentication** - API keys, OAuth Tokens, Basic Authentication
# * **Pagination** - Pages, Data Chunks
# * **Rate Limits** - Pause requests, Retry-After Header
# * **Memory Managenment** - Limited memory, Streaming

# %% [markdown]
# 1. APIs to check Rate Limit and if exceeded, add sleep time before request again

# %%
url = 'https://api.github.com/rate_limit'

response = requests.get(url)
response.json()['rate']['remaining']
# Out:
# 58

# %%
import time

url = 'https://api.github.com/rate_limit'

response = requests.get(url)
remaining = response.json()['rate']['remaining']

if remaining == 0:
  time.sleep(30)

# %% [markdown]
# 2. Authentication Error and code to fix the authentication error using Colab and API KEY

# %%
url = 'https://api.github.com/user'
requests.get(url).json()
# Out:
# {'message': 'Requires authentication',
#  'documentation_url': 'https://docs.github.com/rest/users/users#get-the-authenticated-user',
#  'status': '401'}

# %%
from google.colab import userdata

API_TOKEN = userdata.get('API_TOKEN')

headers = {
    'Authorization': f'Bearer {API_TOKEN}'
}

url = 'https://api.github.com/user'
response = requests.get(url, headers=headers)
response.json()
# Out:
# ---------------------------------------------------------------------------
# SecretNotFoundError                       Traceback (most recent call last)
# <ipython-input-12-1447f83d683f> in <cell line: 0>()
#       3 from google.colab import userdata
#       4
# ----> 5 API_TOKEN = userdata.get('API_TOKEN')
#       6
#       7 headers = {
#
# /usr/local/lib/python3.11/dist-packages/google/colab/userdata.py in get(key)
#      66     raise TimeoutException(key)
#      67   if not resp.get('exists', False):
# ---> 68     raise SecretNotFoundError(key)
#      69   if not resp.get('access', False):
#      70     raise NotebookAccessError(key)
#
# SecretNotFoundError: Secret API_TOKEN does not exist.

# %% [markdown]
# 3. Pagination

# %%
url = 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/events'

response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
# Get link of next page (2)

response.links['next']['url']
# Out:
# 'https://api.github.com/repositories/419661684/events?page=2'

# %%
# while Loop for next page or break if no next page

url = 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/events'

while True:
  response = requests.get(url)
  data = response.json()
  print(len(data))

  if 'next' not in response.links:
    break

  url = response.links['next']['url']
# Out:
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 26

# %% [markdown]
# * Instead of getting all the events data all at once, it's best to get them in chunks.

# %%
# get events data in chunks

import requests

def events_getter():
  url = 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/events'

  while True:
    response = requests.get(url)
    data = response.json()
    yield data

    if 'next' not in response.links:
      break

    url = response.links['next']['url']

# %%
events_pages = events_getter()

for event_page in events_pages:
  print(event_page)
# Out:
# [{'id': '48993156691', 'type': 'WatchEvent', 'actor': {'id': 129647123, 'login': 'Abdullakhan110100100', 'display_login': 'Abdullakhan110100100', 'gravatar_id': '', 'url': 'https://api.github.com/users/Abdullakhan110100100', 'avatar_url': 'https://avatars.githubusercontent.com/u/129647123?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-04-23T21:19:12Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '48992523734', 'type': 'WatchEvent', 'actor': {'id': 204797752, 'login': 'rodrigues39', 'display_login': 'rodrigues39', 'gravatar_id': '', 'url': 'https://api.github.com/users/rodrigues39', 'avatar_url': 'https://avatars.githubusercontent.com/u/204797752?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-04-23T20:57:36Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '48990903472', 'type': 'WatchEvent', 'actor': {'id': 208870789, 'login': 'AndresMLopez', 'display_login': 'AndresMLopez', 'gravatar_id': '', 'url': 'https://api.github.com/users/AndresMLopez', 'avatar_url': 'https://avatars.githubusercontent.com/u/208870789?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-04-23T20:05:04Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '48990405965', 'type': 'ForkEvent', 'actor': {'id': 53873343, 'login': 'JaquanAhmed', 'display_login': 'JaquanAhmed', 'gravatar_id': '', 'url': 'https://api.github.com/users/JaquanAhmed', 'avatar_url': 'https://avatars.githubusercontent.com/u/53873343?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'forkee': {'id': 971617964, 'node_id': 'R_kgDOOem2rA', 'name': 'data-engineering-zoomcamp', 'full_name': 'JaquanAhmed/data-engineering-zoomcamp', 'private': False, 'owner': {'login': 'JaquanAhmed', 'id': 53873343, 'node_id': 'MDQ6VXNlcjUzODczMzQz', 'avatar_url': 'https://avatars.githubusercontent.com/u/53873343?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/JaquanAhmed', 'html_url': 'https://github.com/JaquanAhmed', 'followers_url': 'https://api.github.com/users/JaquanAhmed/followers', 'following_url': 'https://api.github.com/users/JaquanAhmed/following{/other_user}', 'gists_url': 'https://api.github.com/users/JaquanAhmed/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/JaquanAhmed/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/JaquanAhmed/subscriptions', 'organizations_url': 'https://api.github.com/users/JaquanAhmed/orgs', 'repos_url': 'https://api.github.com/users/JaquanAhmed/repos', 'events_url': 'https://api.github.com/users/JaquanAhmed/events{/privacy}', 'received_events_url': 'https://api.github.com/users/JaquanAhmed/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, 'html_url': 'https://github.com/JaquanAhmed/data-engineering-zoomcamp', 'description': 'Data Engineering Zoomcamp is a free nine-week course that covers the fundamentals of data engineering.', 'fork': True, 'url': 'https://api.github.com/repos/JaquanAhm ...
# [{'id': '48941651136', 'type': 'ForkEvent', 'actor': {'id': 170435269, 'login': 'MarvicCCV', 'display_login': 'MarvicCCV', 'gravatar_id': '', 'url': 'https://api.github.com/users/MarvicCCV', 'avatar_url': 'https://avatars.githubusercontent.com/u/170435269?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'forkee': {'id': 970917308, 'node_id': 'R_kgDOOd8FvA', 'name': 'data-engineering-zoomcamp', 'full_name': 'MarvicCCV/data-engineering-zoomcamp', 'private': False, 'owner': {'login': 'MarvicCCV', 'id': 170435269, 'node_id': 'U_kgDOCiiixQ', 'avatar_url': 'https://avatars.githubusercontent.com/u/170435269?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/MarvicCCV', 'html_url': 'https://github.com/MarvicCCV', 'followers_url': 'https://api.github.com/users/MarvicCCV/followers', 'following_url': 'https://api.github.com/users/MarvicCCV/following{/other_user}', 'gists_url': 'https://api.github.com/users/MarvicCCV/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/MarvicCCV/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/MarvicCCV/subscriptions', 'organizations_url': 'https://api.github.com/users/MarvicCCV/orgs', 'repos_url': 'https://api.github.com/users/MarvicCCV/repos', 'events_url': 'https://api.github.com/users/MarvicCCV/events{/privacy}', 'received_events_url': 'https://api.github.com/users/MarvicCCV/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, 'html_url': 'https://github.com/MarvicCCV/data-engineering-zoomcamp', 'description': 'Data Engineering Zoomcamp is a free nine-week course that covers the fundamentals of data engineering.', 'fork': True, 'url': 'https://api.github.com/repos/MarvicCCV/data-engineering-zoomcamp', 'forks_url': 'https://api.github.com/repos/MarvicCCV/data-engineering-zoomcamp/forks', 'keys_url': 'https://api.github.com/repos/MarvicCCV/data-engineering-zoomcamp/keys{/key_id}', 'collaborators_url': 'https://api.github.com/repos/MarvicCCV/data-engineering-zoomcamp/collaborators{/collaborator}', 'teams_url': 'https://api.github.com/repos/MarvicCCV/data-engineering-zoomcamp/teams', 'hooks_url': 'https://api.github.com/repos/MarvicCCV/data-engineering-zoomcamp/hooks', 'issue_events_url': 'https://api.github.com/repos/MarvicCCV/data-engineering-zoomcamp/issues/events{/number}', 'events_url': 'https://api.github.com/repos/MarvicCCV/data-engineering-zoomcamp/events', 'assignees_url': 'https://api.github.com/repos/MarvicCCV/data-engineering-zoomcamp/assignees{/user}', 'branches_url': 'https://api.github.com/repos/MarvicCCV/data-engineering-zoomcamp/branches{/branch}', 'tags_url': 'https://api.github.com/repos/MarvicCCV/data-engineering-zoomcamp/tags', 'blobs_url': 'https://api.github.com/repos/MarvicCCV/data-engineering-zoomcamp/git/blobs{/sha}', 'git_tags_url': 'https://api.github.com/repos/MarvicCCV/data-engineering-zoomcamp/git/tags{/sha}', 'git_refs_url': 'https://api.github.com/repos/MarvicCCV/data-engineering-zoomcamp/git/refs{/sha}', 'trees_url': 'https://api.github.com/repos/MarvicCCV/data-engineering-zoomcamp/git/trees{/sha}', 'statuses_url': 'https://api.github.com/repos/MarvicCCV/data-engineering-zoomcamp/statuses/{sha}', 'languages_url': 'https://api.github.com/repos/MarvicCCV/data-engineering-zoomcamp/languages', 'stargazers_url': 'https://api.github.com/repos/MarvicCCV/data-engineering-zoomcamp/stargazers', 'contributors_url': 'https://api.github.com/repos/MarvicCCV/data-engineering-zoomcamp/contributors', 'subscribers_url': 'https://api.github.com/repos/MarvicCCV/data-engineering-zoomcamp/subscribers', 'subscription_url': 'https://api.github.com/repos/MarvicCCV/data-engineering-zoomcamp/subscription', 'commits_url': 'https://api.github.com/repos/MarvicCCV/data-engineering-zoomcamp/commits{/sha}', 'git_commits_url': 'https://api.github.com/repos/MarvicCCV/data-engineering-zoomcamp/git/commits{/s ...
# [{'id': '48891577031', 'type': 'WatchEvent', 'actor': {'id': 123732243, 'login': 'dcser123', 'display_login': 'dcser123', 'gravatar_id': '', 'url': 'https://api.github.com/users/dcser123', 'avatar_url': 'https://avatars.githubusercontent.com/u/123732243?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-04-21T15:19:38Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '48891232199', 'type': 'WatchEvent', 'actor': {'id': 65561308, 'login': 'AbdurrahmanAshraf', 'display_login': 'AbdurrahmanAshraf', 'gravatar_id': '', 'url': 'https://api.github.com/users/AbdurrahmanAshraf', 'avatar_url': 'https://avatars.githubusercontent.com/u/65561308?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-04-21T15:09:07Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '48889844483', 'type': 'ForkEvent', 'actor': {'id': 58112681, 'login': 'TheOnma', 'display_login': 'TheOnma', 'gravatar_id': '', 'url': 'https://api.github.com/users/TheOnma', 'avatar_url': 'https://avatars.githubusercontent.com/u/58112681?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'forkee': {'id': 970132166, 'node_id': 'R_kgDOOdMKxg', 'name': 'data-engineering-zoomcamp', 'full_name': 'TheOnma/data-engineering-zoomcamp', 'private': False, 'owner': {'login': 'TheOnma', 'id': 58112681, 'node_id': 'MDQ6VXNlcjU4MTEyNjgx', 'avatar_url': 'https://avatars.githubusercontent.com/u/58112681?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/TheOnma', 'html_url': 'https://github.com/TheOnma', 'followers_url': 'https://api.github.com/users/TheOnma/followers', 'following_url': 'https://api.github.com/users/TheOnma/following{/other_user}', 'gists_url': 'https://api.github.com/users/TheOnma/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/TheOnma/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/TheOnma/subscriptions', 'organizations_url': 'https://api.github.com/users/TheOnma/orgs', 'repos_url': 'https://api.github.com/users/TheOnma/repos', 'events_url': 'https://api.github.com/users/TheOnma/events{/privacy}', 'received_events_url': 'https://api.github.com/users/TheOnma/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, 'html_url': 'https://github.com/TheOnma/data-engineering-zoomcamp', 'description': 'Data Engineering Zoomcamp is a free nine-week course that covers the fundamentals of data engineering.', 'fork': True, 'url': 'https://api.github.com/repos/TheOnma/data-engineering-zoomcamp', 'forks_url': 'https://api.github.com/repos/TheOnma/data-engineering-zoomcamp/forks', 'keys_url': 'https://api.github.com/repos/TheOnma/data-engineering-zoomcamp/keys{/key_id}', 'collaborators_url': 'https://api.github.com/repos/TheOnma/data-engineering-zoomcamp/collaborators{/collaborator}', 'teams_url': 'https://api.github.com/repos/TheOnma/data-engineering-zoomcamp/teams', 'hooks_url': 'https://api.github.com/repos/TheOnma/data-engineering-zoomcamp/hooks', 'issue_events_url': 'https://api.github.com/repos/TheOnma/data-engineering-zoomcamp/issues/events{/number}', 'events_url': 'https://api.github.com/repos/TheOnma/data-engineering-zoomcamp/events', 'assignees_url': 'https://api.github.com/repos/TheOnma/data-engineering-zoomcamp/assignees{/user}', 'branc ...
# [{'id': '48866049810', 'type': 'ForkEvent', 'actor': {'id': 70012607, 'login': 'tomy-mentor', 'display_login': 'tomy-mentor', 'gravatar_id': '', 'url': 'https://api.github.com/users/tomy-mentor', 'avatar_url': 'https://avatars.githubusercontent.com/u/70012607?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'forkee': {'id': 969650520, 'node_id': 'R_kgDOOcuxWA', 'name': 'data-engineering-zoomcamp', 'full_name': 'tomy-mentor/data-engineering-zoomcamp', 'private': False, 'owner': {'login': 'tomy-mentor', 'id': 70012607, 'node_id': 'MDQ6VXNlcjcwMDEyNjA3', 'avatar_url': 'https://avatars.githubusercontent.com/u/70012607?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/tomy-mentor', 'html_url': 'https://github.com/tomy-mentor', 'followers_url': 'https://api.github.com/users/tomy-mentor/followers', 'following_url': 'https://api.github.com/users/tomy-mentor/following{/other_user}', 'gists_url': 'https://api.github.com/users/tomy-mentor/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/tomy-mentor/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/tomy-mentor/subscriptions', 'organizations_url': 'https://api.github.com/users/tomy-mentor/orgs', 'repos_url': 'https://api.github.com/users/tomy-mentor/repos', 'events_url': 'https://api.github.com/users/tomy-mentor/events{/privacy}', 'received_events_url': 'https://api.github.com/users/tomy-mentor/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, 'html_url': 'https://github.com/tomy-mentor/data-engineering-zoomcamp', 'description': 'Data Engineering Zoomcamp is a free nine-week course that covers the fundamentals of data engineering.', 'fork': True, 'url': 'https://api.github.com/repos/tomy-mentor/data-engineering-zoomcamp', 'forks_url': 'https://api.github.com/repos/tomy-mentor/data-engineering-zoomcamp/forks', 'keys_url': 'https://api.github.com/repos/tomy-mentor/data-engineering-zoomcamp/keys{/key_id}', 'collaborators_url': 'https://api.github.com/repos/tomy-mentor/data-engineering-zoomcamp/collaborators{/collaborator}', 'teams_url': 'https://api.github.com/repos/tomy-mentor/data-engineering-zoomcamp/teams', 'hooks_url': 'https://api.github.com/repos/tomy-mentor/data-engineering-zoomcamp/hooks', 'issue_events_url': 'https://api.github.com/repos/tomy-mentor/data-engineering-zoomcamp/issues/events{/number}', 'events_url': 'https://api.github.com/repos/tomy-mentor/data-engineering-zoomcamp/events', 'assignees_url': 'https://api.github.com/repos/tomy-mentor/data-engineering-zoomcamp/assignees{/user}', 'branches_url': 'https://api.github.com/repos/tomy-mentor/data-engineering-zoomcamp/branches{/branch}', 'tags_url': 'https://api.github.com/repos/tomy-mentor/data-engineering-zoomcamp/tags', 'blobs_url': 'https://api.github.com/repos/tomy-mentor/data-engineering-zoomcamp/git/blobs{/sha}', 'git_tags_url': 'https://api.github.com/repos/tomy-mentor/data-engineering-zoomcamp/git/tags{/sha}', 'git_refs_url': 'https://api.github.com/repos/tomy-mentor/data-engineering-zoomcamp/git/refs{/sha}', 'trees_url': 'https://api.github.com/repos/tomy-mentor/data-engineering-zoomcamp/git/trees{/sha}', 'statuses_url': 'https://api.github.com/repos/tomy-mentor/data-engineering-zoomcamp/statuses/{sha}', 'languages_url': 'https://api.github.com/repos/tomy-mentor/data-engineering-zoomcamp/languages', 'stargazers_url': 'https://api.github.com/repos/tomy-mentor/data-engineering-zoomcamp/stargazers', 'contributors_url': 'https://api.github.com/repos/tomy-mentor/data-engineering-zoomcamp/contributors', 'subscribers_url': 'https://api.github.com/repos/tomy-mentor/data-engineering-zoomcamp/subscribers', 'subscription_url': 'https://api.github.com/repos/tomy-mentor/data-engineering-zoomcamp/subscription', 'commits_url': 'https://api.github.com/repos/tomy-mentor/data-engineering-zoomcamp/commits{/sha}', 'git_commits_url' ...
# [{'id': '48852676522', 'type': 'WatchEvent', 'actor': {'id': 194891283, 'login': 'GianLu1s', 'display_login': 'GianLu1s', 'gravatar_id': '', 'url': 'https://api.github.com/users/GianLu1s', 'avatar_url': 'https://avatars.githubusercontent.com/u/194891283?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-04-19T17:05:19Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '48852398780', 'type': 'WatchEvent', 'actor': {'id': 106329078, 'login': 'jotaaguiar', 'display_login': 'jotaaguiar', 'gravatar_id': '', 'url': 'https://api.github.com/users/jotaaguiar', 'avatar_url': 'https://avatars.githubusercontent.com/u/106329078?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-04-19T16:39:09Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '48851060305', 'type': 'WatchEvent', 'actor': {'id': 25855879, 'login': 'TangoMango223', 'display_login': 'TangoMango223', 'gravatar_id': '', 'url': 'https://api.github.com/users/TangoMango223', 'avatar_url': 'https://avatars.githubusercontent.com/u/25855879?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-04-19T14:35:08Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '48851012879', 'type': 'WatchEvent', 'actor': {'id': 156104354, 'login': 'uelkerd', 'display_login': 'uelkerd', 'gravatar_id': '', 'url': 'https://api.github.com/users/uelkerd', 'avatar_url': 'https://avatars.githubusercontent.com/u/156104354?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-04-19T14:30:38Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '48850890517', 'type': 'ForkEvent', 'actor': {'id': 39306392, 'login': 'florienzh4x', 'display_login': 'florienzh4x', 'gravatar_id': '', 'url': 'https://api.github.com/users/florienzh4x', 'avatar_url': 'https://avatars.githubusercontent.com/u/39306392?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'forkee': {'id': 969159233, 'node_id': 'R_kgDOOcQyQQ', 'name': 'data-engineering-zoomcamp', 'full_name': 'florienzh4x/data-engineering-zoomcamp', 'private': False, 'owner': {'login': 'florienzh4x', 'id': 39306392, 'node_id': 'MDQ6VXNlcjM5MzA2Mzky', 'avatar_url': 'https://avatars.githubusercontent.com/u/39306392?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/florienzh4x', 'html_url': 'https://github.com/florienzh4x', 'followers_url': 'https://api.github.com/users/florienzh4x/followers', 'following_url': 'https://api.github.com/users/florienzh4x/following{/other_user}', 'gists_url': 'https://api.github.com/users/florienzh4x/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/florienzh4x/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.gith ...
# [{'id': '48815301735', 'type': 'WatchEvent', 'actor': {'id': 51940642, 'login': 'greg-maggard', 'display_login': 'greg-maggard', 'gravatar_id': '', 'url': 'https://api.github.com/users/greg-maggard', 'avatar_url': 'https://avatars.githubusercontent.com/u/51940642?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-04-18T02:19:31Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '48813332758', 'type': 'ForkEvent', 'actor': {'id': 28595174, 'login': 'luoxinru2017', 'display_login': 'luoxinru2017', 'gravatar_id': '', 'url': 'https://api.github.com/users/luoxinru2017', 'avatar_url': 'https://avatars.githubusercontent.com/u/28595174?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'forkee': {'id': 968354636, 'node_id': 'R_kgDOObfrTA', 'name': 'data-engineering-zoomcamp', 'full_name': 'luoxinru2017/data-engineering-zoomcamp', 'private': False, 'owner': {'login': 'luoxinru2017', 'id': 28595174, 'node_id': 'MDQ6VXNlcjI4NTk1MTc0', 'avatar_url': 'https://avatars.githubusercontent.com/u/28595174?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/luoxinru2017', 'html_url': 'https://github.com/luoxinru2017', 'followers_url': 'https://api.github.com/users/luoxinru2017/followers', 'following_url': 'https://api.github.com/users/luoxinru2017/following{/other_user}', 'gists_url': 'https://api.github.com/users/luoxinru2017/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/luoxinru2017/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/luoxinru2017/subscriptions', 'organizations_url': 'https://api.github.com/users/luoxinru2017/orgs', 'repos_url': 'https://api.github.com/users/luoxinru2017/repos', 'events_url': 'https://api.github.com/users/luoxinru2017/events{/privacy}', 'received_events_url': 'https://api.github.com/users/luoxinru2017/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, 'html_url': 'https://github.com/luoxinru2017/data-engineering-zoomcamp', 'description': 'Data Engineering Zoomcamp is a free nine-week course that covers the fundamentals of data engineering.', 'fork': True, 'url': 'https://api.github.com/repos/luoxinru2017/data-engineering-zoomcamp', 'forks_url': 'https://api.github.com/repos/luoxinru2017/data-engineering-zoomcamp/forks', 'keys_url': 'https://api.github.com/repos/luoxinru2017/data-engineering-zoomcamp/keys{/key_id}', 'collaborators_url': 'https://api.github.com/repos/luoxinru2017/data-engineering-zoomcamp/collaborators{/collaborator}', 'teams_url': 'https://api.github.com/repos/luoxinru2017/data-engineering-zoomcamp/teams', 'hooks_url': 'https://api.github.com/repos/luoxinru2017/data-engineering-zoomcamp/hooks', 'issue_events_url': 'https://api.github.com/repos/luoxinru2017/data-engineering-zoomcamp/issues/events{/number}', 'events_url': 'https://api.github.com/repos/luoxinru2017/data-engineering-zoomcamp/events', 'assignees_url': 'https://api.github.com/repos/luoxinru2017/data-engineering-zoomcamp/assignees{/user}', 'branches_url': 'https://api.github.com/repos/luoxinru2017/data-engineering-zoomcamp/branches{/branch}', 'tags_url': 'https://api.github.com/repos/luoxinru2017/data-engineering-zoomcamp/tags', 'blobs_url': 'https://api.github.com/repos/luoxinru2017/data-engineering-zoomcamp/git/blobs{/sha}', 'git_tags_url': 'https://api.github.com/repos/luoxinru2017/data-engineering-zoomcamp/git/tags{/sha}', 'git_refs_url': 'https://api.github.com/repos/luoxinru2017/data-engineering-zoomcamp/git/refs{/sha}', 'trees_url': 'https://api.github.com/repos/luoxinru2017/data-engineering-zoomcamp/git/ ...
# [{'id': '48727771458', 'type': 'WatchEvent', 'actor': {'id': 110506416, 'login': 'nathanxiang000', 'display_login': 'nathanxiang000', 'gravatar_id': '', 'url': 'https://api.github.com/users/nathanxiang000', 'avatar_url': 'https://avatars.githubusercontent.com/u/110506416?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-04-16T01:33:03Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '48726891840', 'type': 'WatchEvent', 'actor': {'id': 171283420, 'login': 'johna-lee', 'display_login': 'johna-lee', 'gravatar_id': '', 'url': 'https://api.github.com/users/johna-lee', 'avatar_url': 'https://avatars.githubusercontent.com/u/171283420?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-04-16T00:46:20Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '48724899044', 'type': 'WatchEvent', 'actor': {'id': 100543093, 'login': 'luisricardo-ai', 'display_login': 'luisricardo-ai', 'gravatar_id': '', 'url': 'https://api.github.com/users/luisricardo-ai', 'avatar_url': 'https://avatars.githubusercontent.com/u/100543093?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-04-15T22:57:02Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '48724038324', 'type': 'WatchEvent', 'actor': {'id': 62505532, 'login': 'Vaishnavi57', 'display_login': 'Vaishnavi57', 'gravatar_id': '', 'url': 'https://api.github.com/users/Vaishnavi57', 'avatar_url': 'https://avatars.githubusercontent.com/u/62505532?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-04-15T22:16:20Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '48722612325', 'type': 'WatchEvent', 'actor': {'id': 62997533, 'login': 'Amir380-A', 'display_login': 'Amir380-A', 'gravatar_id': '', 'url': 'https://api.github.com/users/Amir380-A', 'avatar_url': 'https://avatars.githubusercontent.com/u/62997533?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-04-15T21:18:16Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '48722277756', 'type': 'WatchEvent', 'actor': {'id': 123993968, 'login': 'ronaldespinozaa', 'display_login': 'ronaldespinozaa', 'gravatar_id': '', 'url': 'https://api.github.com/users/ronaldespinozaa', 'avatar_url': 'https://avatars.githubusercontent.com/u/123993968?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'create ...
# [{'id': '48685284444', 'type': 'WatchEvent', 'actor': {'id': 76592997, 'login': 'sathyapriyanb', 'display_login': 'sathyapriyanb', 'gravatar_id': '', 'url': 'https://api.github.com/users/sathyapriyanb', 'avatar_url': 'https://avatars.githubusercontent.com/u/76592997?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-04-15T04:48:45Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '48683609646', 'type': 'ForkEvent', 'actor': {'id': 48563295, 'login': 'SanoTaco', 'display_login': 'SanoTaco', 'gravatar_id': '', 'url': 'https://api.github.com/users/SanoTaco', 'avatar_url': 'https://avatars.githubusercontent.com/u/48563295?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'forkee': {'id': 966512213, 'node_id': 'R_kgDOOZvOVQ', 'name': 'data-engineering-zoomcamp', 'full_name': 'SanoTaco/data-engineering-zoomcamp', 'private': False, 'owner': {'login': 'SanoTaco', 'id': 48563295, 'node_id': 'MDQ6VXNlcjQ4NTYzMjk1', 'avatar_url': 'https://avatars.githubusercontent.com/u/48563295?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/SanoTaco', 'html_url': 'https://github.com/SanoTaco', 'followers_url': 'https://api.github.com/users/SanoTaco/followers', 'following_url': 'https://api.github.com/users/SanoTaco/following{/other_user}', 'gists_url': 'https://api.github.com/users/SanoTaco/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/SanoTaco/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/SanoTaco/subscriptions', 'organizations_url': 'https://api.github.com/users/SanoTaco/orgs', 'repos_url': 'https://api.github.com/users/SanoTaco/repos', 'events_url': 'https://api.github.com/users/SanoTaco/events{/privacy}', 'received_events_url': 'https://api.github.com/users/SanoTaco/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, 'html_url': 'https://github.com/SanoTaco/data-engineering-zoomcamp', 'description': 'Data Engineering Zoomcamp is a free nine-week course that covers the fundamentals of data engineering.', 'fork': True, 'url': 'https://api.github.com/repos/SanoTaco/data-engineering-zoomcamp', 'forks_url': 'https://api.github.com/repos/SanoTaco/data-engineering-zoomcamp/forks', 'keys_url': 'https://api.github.com/repos/SanoTaco/data-engineering-zoomcamp/keys{/key_id}', 'collaborators_url': 'https://api.github.com/repos/SanoTaco/data-engineering-zoomcamp/collaborators{/collaborator}', 'teams_url': 'https://api.github.com/repos/SanoTaco/data-engineering-zoomcamp/teams', 'hooks_url': 'https://api.github.com/repos/SanoTaco/data-engineering-zoomcamp/hooks', 'issue_events_url': 'https://api.github.com/repos/SanoTaco/data-engineering-zoomcamp/issues/events{/number}', 'events_url': 'https://api.github.com/repos/SanoTaco/data-engineering-zoomcamp/events', 'assignees_url': 'https://api.github.com/repos/SanoTaco/data-engineering-zoomcamp/assignees{/user}', 'branches_url': 'https://api.github.com/repos/SanoTaco/data-engineering-zoomcamp/branches{/branch}', 'tags_url': 'https://api.github.com/repos/SanoTaco/data-engineering-zoomcamp/tags', 'blobs_url': 'https://api.github.com/repos/SanoTaco/data-engineering-zoomcamp/git/blobs{/sha}', 'git_tags_url': 'https://api.github.com/repos/SanoTaco/data-engineering-zoomcamp/git/tags{/sha}', 'git_refs_url': 'https://api.github.com/repos/SanoTaco/data-engineering-zoomcamp/git/refs{/sha}', 'trees_url': 'https://api.github.com/repos/SanoTaco/data-engineering-zoomcamp/git/trees{/sha}', 'statuses_url': 'https://api.github.com/repos/SanoTaco/data-engineering-zoomcamp/statuses/{sha}', 'languages_ur ...
# [{'id': '48631995668', 'type': 'ForkEvent', 'actor': {'id': 23364419, 'login': 'hmaw', 'display_login': 'hmaw', 'gravatar_id': '', 'url': 'https://api.github.com/users/hmaw', 'avatar_url': 'https://avatars.githubusercontent.com/u/23364419?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'forkee': {'id': 965732159, 'node_id': 'R_kgDOOY_nPw', 'name': 'HMAWdata-engineering-zoomcamp', 'full_name': 'hmaw/HMAWdata-engineering-zoomcamp', 'private': False, 'owner': {'login': 'hmaw', 'id': 23364419, 'node_id': 'MDQ6VXNlcjIzMzY0NDE5', 'avatar_url': 'https://avatars.githubusercontent.com/u/23364419?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/hmaw', 'html_url': 'https://github.com/hmaw', 'followers_url': 'https://api.github.com/users/hmaw/followers', 'following_url': 'https://api.github.com/users/hmaw/following{/other_user}', 'gists_url': 'https://api.github.com/users/hmaw/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/hmaw/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/hmaw/subscriptions', 'organizations_url': 'https://api.github.com/users/hmaw/orgs', 'repos_url': 'https://api.github.com/users/hmaw/repos', 'events_url': 'https://api.github.com/users/hmaw/events{/privacy}', 'received_events_url': 'https://api.github.com/users/hmaw/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, 'html_url': 'https://github.com/hmaw/HMAWdata-engineering-zoomcamp', 'description': 'Data Engineering Zoomcamp is a free nine-week course that covers the fundamentals of data engineering.', 'fork': True, 'url': 'https://api.github.com/repos/hmaw/HMAWdata-engineering-zoomcamp', 'forks_url': 'https://api.github.com/repos/hmaw/HMAWdata-engineering-zoomcamp/forks', 'keys_url': 'https://api.github.com/repos/hmaw/HMAWdata-engineering-zoomcamp/keys{/key_id}', 'collaborators_url': 'https://api.github.com/repos/hmaw/HMAWdata-engineering-zoomcamp/collaborators{/collaborator}', 'teams_url': 'https://api.github.com/repos/hmaw/HMAWdata-engineering-zoomcamp/teams', 'hooks_url': 'https://api.github.com/repos/hmaw/HMAWdata-engineering-zoomcamp/hooks', 'issue_events_url': 'https://api.github.com/repos/hmaw/HMAWdata-engineering-zoomcamp/issues/events{/number}', 'events_url': 'https://api.github.com/repos/hmaw/HMAWdata-engineering-zoomcamp/events', 'assignees_url': 'https://api.github.com/repos/hmaw/HMAWdata-engineering-zoomcamp/assignees{/user}', 'branches_url': 'https://api.github.com/repos/hmaw/HMAWdata-engineering-zoomcamp/branches{/branch}', 'tags_url': 'https://api.github.com/repos/hmaw/HMAWdata-engineering-zoomcamp/tags', 'blobs_url': 'https://api.github.com/repos/hmaw/HMAWdata-engineering-zoomcamp/git/blobs{/sha}', 'git_tags_url': 'https://api.github.com/repos/hmaw/HMAWdata-engineering-zoomcamp/git/tags{/sha}', 'git_refs_url': 'https://api.github.com/repos/hmaw/HMAWdata-engineering-zoomcamp/git/refs{/sha}', 'trees_url': 'https://api.github.com/repos/hmaw/HMAWdata-engineering-zoomcamp/git/trees{/sha}', 'statuses_url': 'https://api.github.com/repos/hmaw/HMAWdata-engineering-zoomcamp/statuses/{sha}', 'languages_url': 'https://api.github.com/repos/hmaw/HMAWdata-engineering-zoomcamp/languages', 'stargazers_url': 'https://api.github.com/repos/hmaw/HMAWdata-engineering-zoomcamp/stargazers', 'contributors_url': 'https://api.github.com/repos/hmaw/HMAWdata-engineering-zoomcamp/contributors', 'subscribers_url': 'https://api.github.com/repos/hmaw/HMAWdata-engineering-zoomcamp/subscribers', 'subscription_url': 'https://api.github.com/repos/hmaw/HMAWdata-engineering-zoomcamp/subscription', 'commits_url': 'https://api.github.com/repos/hmaw/HMAWdata-engineering-zoomcamp/commits{/sha}', 'git_commits_url': 'https://api.github.com/repos/hmaw/HMAWdata-engineering-zoomcamp/git/commits{/sha}', 'comments_url': 'https://api.github.com/repos/hmaw/HMAWdata-engineering-zoomcamp/comme ...
# [{'id': '48615993501', 'type': 'ForkEvent', 'actor': {'id': 31289200, 'login': 'dinuvdm', 'display_login': 'dinuvdm', 'gravatar_id': '', 'url': 'https://api.github.com/users/dinuvdm', 'avatar_url': 'https://avatars.githubusercontent.com/u/31289200?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'forkee': {'id': 965208048, 'node_id': 'R_kgDOOYfn8A', 'name': 'data-engineering-zoomcamp', 'full_name': 'dinuvdm/data-engineering-zoomcamp', 'private': False, 'owner': {'login': 'dinuvdm', 'id': 31289200, 'node_id': 'MDQ6VXNlcjMxMjg5MjAw', 'avatar_url': 'https://avatars.githubusercontent.com/u/31289200?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/dinuvdm', 'html_url': 'https://github.com/dinuvdm', 'followers_url': 'https://api.github.com/users/dinuvdm/followers', 'following_url': 'https://api.github.com/users/dinuvdm/following{/other_user}', 'gists_url': 'https://api.github.com/users/dinuvdm/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/dinuvdm/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/dinuvdm/subscriptions', 'organizations_url': 'https://api.github.com/users/dinuvdm/orgs', 'repos_url': 'https://api.github.com/users/dinuvdm/repos', 'events_url': 'https://api.github.com/users/dinuvdm/events{/privacy}', 'received_events_url': 'https://api.github.com/users/dinuvdm/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, 'html_url': 'https://github.com/dinuvdm/data-engineering-zoomcamp', 'description': 'Data Engineering Zoomcamp is a free nine-week course that covers the fundamentals of data engineering.', 'fork': True, 'url': 'https://api.github.com/repos/dinuvdm/data-engineering-zoomcamp', 'forks_url': 'https://api.github.com/repos/dinuvdm/data-engineering-zoomcamp/forks', 'keys_url': 'https://api.github.com/repos/dinuvdm/data-engineering-zoomcamp/keys{/key_id}', 'collaborators_url': 'https://api.github.com/repos/dinuvdm/data-engineering-zoomcamp/collaborators{/collaborator}', 'teams_url': 'https://api.github.com/repos/dinuvdm/data-engineering-zoomcamp/teams', 'hooks_url': 'https://api.github.com/repos/dinuvdm/data-engineering-zoomcamp/hooks', 'issue_events_url': 'https://api.github.com/repos/dinuvdm/data-engineering-zoomcamp/issues/events{/number}', 'events_url': 'https://api.github.com/repos/dinuvdm/data-engineering-zoomcamp/events', 'assignees_url': 'https://api.github.com/repos/dinuvdm/data-engineering-zoomcamp/assignees{/user}', 'branches_url': 'https://api.github.com/repos/dinuvdm/data-engineering-zoomcamp/branches{/branch}', 'tags_url': 'https://api.github.com/repos/dinuvdm/data-engineering-zoomcamp/tags', 'blobs_url': 'https://api.github.com/repos/dinuvdm/data-engineering-zoomcamp/git/blobs{/sha}', 'git_tags_url': 'https://api.github.com/repos/dinuvdm/data-engineering-zoomcamp/git/tags{/sha}', 'git_refs_url': 'https://api.github.com/repos/dinuvdm/data-engineering-zoomcamp/git/refs{/sha}', 'trees_url': 'https://api.github.com/repos/dinuvdm/data-engineering-zoomcamp/git/trees{/sha}', 'statuses_url': 'https://api.github.com/repos/dinuvdm/data-engineering-zoomcamp/statuses/{sha}', 'languages_url': 'https://api.github.com/repos/dinuvdm/data-engineering-zoomcamp/languages', 'stargazers_url': 'https://api.github.com/repos/dinuvdm/data-engineering-zoomcamp/stargazers', 'contributors_url': 'https://api.github.com/repos/dinuvdm/data-engineering-zoomcamp/contributors', 'subscribers_url': 'https://api.github.com/repos/dinuvdm/data-engineering-zoomcamp/subscribers', 'subscription_url': 'https://api.github.com/repos/dinuvdm/data-engineering-zoomcamp/subscription', 'commits_url': 'https://api.github.com/repos/dinuvdm/data-engineering-zoomcamp/commits{/sha}', 'git_commits_url': 'https://api.github.com/repos/dinuvdm/data-engineering-zoomcamp/git/commits{/sha}', 'comments_url': 'https://api.github.com/repos/dinuvdm/data-engineering ...

# %% [markdown]
# ### ***4. Normalizing Data***
#
# This is the conversion of the retrieved json unstructured data into a tabular structured data. It means all **nested structures** (like dictionaries and lists) need to be flattened, to make it easier to store and query in a database or a dataframe

# %%
# get one event page
event = event_page[0]
event
# Out:
# {'id': '48615993501',
#  'type': 'ForkEvent',
#  'actor': {'id': 31289200,
#   'login': 'dinuvdm',
#   'display_login': 'dinuvdm',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/dinuvdm',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/31289200?'},
#  'repo': {'id': 419661684,
#   'name': 'DataTalksClub/data-engineering-zoomcamp',
#   'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'},
#  'payload': {'forkee': {'id': 965208048,
#    'node_id': 'R_kgDOOYfn8A',
#    'name': 'data-engineering-zoomcamp',
#    'full_name': 'dinuvdm/data-engineering-zoomcamp',
#    'private': False,
#    'owner': {'login': 'dinuvdm',
#     'id': 31289200,
#     'node_id': 'MDQ6VXNlcjMxMjg5MjAw',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/31289200?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/dinuvdm',
#     'html_url': 'https://github.com/dinuvdm',
#     'followers_url': 'https://api.github.com/users/dinuvdm/followers',
#     'following_url': 'https://api.github.com/users/dinuvdm/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/dinuvdm/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/dinuvdm/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/dinuvdm/subscriptions',
#     'organizations_url': 'https://api.github.com/users/dinuvdm/orgs',
#     'repos_url': 'https://api.github.com/users/dinuvdm/repos',
#     'events_url': 'https://api.github.com/users/dinuvdm/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/dinuvdm/received_events',
#     'type': 'User',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'html_url': 'https://github.com/dinuvdm/data-engineering-zoomcamp',
#    'description': 'Data Engineering Zoomcamp is a free nine-week course that covers the fundamentals of data engineering.',
#    'fork': True,
#    'url': 'https://api.github.com/repos/dinuvdm/data-engineering-zoomcamp',
#    'forks_url': 'https://api.github.com/repos/dinuvdm/data-engineering-zoomcamp/forks',
#    'keys_url': 'https://api.github.com/repos/dinuvdm/data-engineering-zoomcamp/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/dinuvdm/data-engineering-zoomcamp/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/dinuvdm/data-engineering-zoomcamp/teams',
#    'hooks_url': 'https://api.github.com/repos/dinuvdm/data-engineering-zoomcamp/hooks',
#    'issue_events_url': 'https://api.github.com/repos/dinuvdm/data-engineering-zoomcamp/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/dinuvdm/data-engineering-zoomcamp/events',
#    'assignees_url': 'https://api.github.com/repos/dinuvdm/data-engineering-zoomcamp/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/dinuvdm/data-engineering-zoomcamp/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/dinuvdm/data-engineering-zoomcamp/tags',
#    'blobs_url': 'https://api.github.com/repos/dinuvdm/data-engineering-zoomcamp/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/dinuvdm/data-engineering-zoomcamp/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/dinuvdm/data-engineering-zoomcamp/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/dinuvdm/data-engineering-zoomcamp/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/dinuvdm/data-engineering-zoomcamp/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/dinuvdm/data-engineering-zoomcamp/languages',
#    'stargazers_url': 'https://api.github.com/repos/dinuvdm/data-engineering-zoomcamp/stargazers',
#    'contributors_url': 'https://api.github.com/repos/dinuvdm/data-engineering-zoomcamp/contributors',
#    'subscribers_url': 'https://api.github.com/repos/dinuvdm/data-engineering-zoomcamp/subscribers',
#    'subscription_url': 'https://api.github.com/repos/dinuvdm/data-engineering-zoomcamp/subscription',
#    'commits_url': 'https://api.github.com/repos/dinuvdm/data-engineering-zoomcamp/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/dinuvdm/data-engineering-zoomcamp/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/dinuvdm/data-engineering-zoomcamp/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/dinuvdm/data-engineering-zoomcamp/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/dinuvdm/data-engineering-zoomcamp/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/dinuvdm/data-engineering-zoomcamp/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/dinuvdm/data-engineering-zoomcamp/merges',
#    'archive_url': 'https://api.github.com/repos/dinuvdm/data-engineering-zoomcamp/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/dinuvdm/data-engineering-zoomcamp/downloads',
#    'issues_url': 'https://api.github.com/repos/dinuvdm/data-engineering-zoomcamp/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/dinuvdm/data-engineering-zoomcamp/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/dinuvdm/data-engineering-zoomcamp/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/dinuvdm/data-engineering-zoomcamp/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/dinuvdm/data-engineering-zoomcamp/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/dinuvdm/data-engineering-zoomcamp/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/dinuvdm/data-engineering-zoomcamp/deployments',
#    'created_at': '2025-04-12T16:46:32Z',
#    'updated_at': '2025-04-12T16:46:32Z',
#    'pushed_at': '2025-04-01T15:40:56Z',
#    'git_url': 'git://github.com/dinuvdm/data-engineering-zoomcamp.git',
#    'ssh_url': 'git@github.com:dinuvdm/data-engineering-zoomcamp.git',
#    'clone_url': 'https://github.com/dinuvdm/data-engineering-zoomcamp.git',
#    'svn_url': 'https://github.com/dinuvdm/data-engineering-zoomcamp',
#    'homepage': '',
#    'size': 8731,
#    'stargazers_count': 0,
#    'watchers_count': 0,
#    'language': None,
#    'has_issues': False,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 0,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 0,
#    'license': None,
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 0,
#    'open_issues': 0,
#    'watchers': 0,
#    'default_branch': 'main',
#    'public': True}},
#  'public': True,
#  'created_at': '2025-04-12T16:46:33Z',
#  'org': {'id': 72699292,
#   'login': 'DataTalksClub',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/orgs/DataTalksClub',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}

# %%
# Normalize some keys from the events

def process_events(event):
  result = {}

  result['id'] = event['id']
  result['type'] = event['type']
  result['public'] = event['public']
  result['created_at'] = event['created_at']

  result['actor__id'] = event['actor']['id']  # double underscore for nested dictionaries
  result['actor__login'] = event['actor']['login']

  return result

# %%
process_events(event)
# Out:
# {'id': '48615993501',
#  'type': 'ForkEvent',
#  'public': True,
#  'created_at': '2025-04-12T16:46:33Z',
#  'actor__id': 31289200,
#  'actor__login': 'dinuvdm'}

# %%
# iterate and apply above function to all events

processed_events = []

for event in event_page:
  processed_event = process_events(event)
  processed_events.append(processed_event)

processed_events
# Out:
# [{'id': '48615993501',
#   'type': 'ForkEvent',
#   'public': True,
#   'created_at': '2025-04-12T16:46:33Z',
#   'actor__id': 31289200,
#   'actor__login': 'dinuvdm'},
#  {'id': '48615597375',
#   'type': 'ForkEvent',
#   'public': True,
#   'created_at': '2025-04-12T16:09:52Z',
#   'actor__id': 150928706,
#   'actor__login': 'renad-lab'},
#  {'id': '48615497440',
#   'type': 'WatchEvent',
#   'public': True,
#   'created_at': '2025-04-12T16:01:04Z',
#   'actor__id': 135336193,
#   'actor__login': 'fabriziofranchitti'},
#  {'id': '48615147964',
#   'type': 'WatchEvent',
#   'public': True,
#   'created_at': '2025-04-12T15:28:33Z',
#   'actor__id': 70435178,
#   'actor__login': 'Massinho91'},
#  {'id': '48614660649',
#   'type': 'WatchEvent',
#   'public': True,
#   'created_at': '2025-04-12T14:45:47Z',
#   'actor__id': 74074514,
#   'actor__login': 'omarkhaled122'},
#  {'id': '48614602772',
#   'type': 'WatchEvent',
#   'public': True,
#   'created_at': '2025-04-12T14:40:29Z',
#   'actor__id': 88022389,
#   'actor__login': 'ajit4518'},
#  {'id': '48614453493',
#   'type': 'WatchEvent',
#   'public': True,
#   'created_at': '2025-04-12T14:27:09Z',
#   'actor__id': 59304853,
#   'actor__login': 'sochikenny'},
#  {'id': '48614181838',
#   'type': 'ForkEvent',
#   'public': True,
#   'created_at': '2025-04-12T14:04:27Z',
#   'actor__id': 10475586,
#   'actor__login': 'pala2003'},
#  {'id': '48614104272',
#   'type': 'WatchEvent',
#   'public': True,
#   'created_at': '2025-04-12T13:57:34Z',
#   'actor__id': 101134041,
#   'actor__login': 'AhmedDandash'},
#  {'id': '48614020085',
#   'type': 'WatchEvent',
#   'public': True,
#   'created_at': '2025-04-12T13:49:23Z',
#   'actor__id': 10475586,
#   'actor__login': 'pala2003'},
#  {'id': '48611222324',
#   'type': 'WatchEvent',
#   'public': True,
#   'created_at': '2025-04-12T09:27:02Z',
#   'actor__id': 15324160,
#   'actor__login': 'LeMaxV'},
#  {'id': '48611203144',
#   'type': 'WatchEvent',
#   'public': True,
#   'created_at': '2025-04-12T09:25:09Z',
#   'actor__id': 111711637,
#   'actor__login': 'MrRoberST3'},
#  {'id': '48610418669',
#   'type': 'WatchEvent',
#   'public': True,
#   'created_at': '2025-04-12T08:08:49Z',
#   'actor__id': 25663748,
#   'actor__login': 'ulisesaguilar17'},
#  {'id': '48608922246',
#   'type': 'WatchEvent',
#   'public': True,
#   'created_at': '2025-04-12T05:39:45Z',
#   'actor__id': 52683046,
#   'actor__login': 'CoderAtGithub'},
#  {'id': '48608549581',
#   'type': 'WatchEvent',
#   'public': True,
#   'created_at': '2025-04-12T05:01:35Z',
#   'actor__id': 84787468,
#   'actor__login': 'neeraj-a2912'},
#  {'id': '48608342341',
#   'type': 'ForkEvent',
#   'public': True,
#   'created_at': '2025-04-12T04:39:13Z',
#   'actor__id': 205798518,
#   'actor__login': 'Nikhil-Jerome'},
#  {'id': '48607699200',
#   'type': 'WatchEvent',
#   'public': True,
#   'created_at': '2025-04-12T03:32:57Z',
#   'actor__id': 8486819,
#   'actor__login': 'wenwenkong'},
#  {'id': '48606658043',
#   'type': 'ForkEvent',
#   'public': True,
#   'created_at': '2025-04-12T01:50:31Z',
#   'actor__id': 9623693,
#   'actor__login': 'poiu72'},
#  {'id': '48606654417',
#   'type': 'WatchEvent',
#   'public': True,
#   'created_at': '2025-04-12T01:50:12Z',
#   'actor__id': 9623693,
#   'actor__login': 'poiu72'},
#  {'id': '48603822301',
#   'type': 'WatchEvent',
#   'public': True,
#   'created_at': '2025-04-11T22:20:39Z',
#   'actor__id': 162624833,
#   'actor__login': 'kjanicky'},
#  {'id': '48603293129',
#   'type': 'ForkEvent',
#   'public': True,
#   'created_at': '2025-04-11T21:52:35Z',
#   'actor__id': 47690096,
#   'actor__login': 'digitalNomadKg'},
#  {'id': '48603289926',
#   'type': 'WatchEvent',
#   'public': True,
#   'created_at': '2025-04-11T21:52:25Z',
#   'actor__id': 47690096,
#   'actor__login': 'digitalNomadKg'},
#  {'id': '48601736639',
#   'type': 'WatchEvent',
#   'public': True,
#   'created_at': '2025-04-11T20:44:21Z',
#   'actor__id': 131834608,
#   'actor__login': 'taniomi'},
#  {'id': '48601092982',
#   'type': 'WatchEvent',
#   'public': True,
#   'created_at': '2025-04-11T20:19:32Z',
#   'actor__id': 194099656,
#   'actor__login': 'VexDoc'},
#  {'id': '48598895606',
#   'type': 'WatchEvent',
#   'public': True,
#   'created_at': '2025-04-11T19:01:08Z',
#   'actor__id': 5679957,
#   'actor__login': 'nlyf'},
#  {'id': '48597225431',
#   'type': 'WatchEvent',
#   'public': True,
#   'created_at': '2025-04-11T18:06:45Z',
#   'actor__id': 63077899,
#   'actor__login': 'ccbaumler'}]

# %%
# convert created_at from string to datetime format

from datetime import datetime

def process_events(event):
  result = {}

  result['id'] = event['id']
  result['type'] = event['type']
  result['public'] = event['public']

  parsed_timestamp = datetime.fromisoformat(event['created_at'])
  result['created_at'] = parsed_timestamp.timestamp()

  result['actor__id'] = event['actor']['id']  # double underscore for nested dictionaries
  result['actor__login'] = event['actor']['login']

  return result

process_events(event)
# Out:
# {'id': '48615993501',
#  'type': 'ForkEvent',
#  'public': True,
#  'created_at': 1744476393.0,
#  'actor__id': 31289200,
#  'actor__login': 'dinuvdm'}
